# %% [markdown]
# # Step 6 Robustness and Polish
#
# This notebook is a lightweight QA companion for Step 6 outputs.
# It reads generated CSV/JSON artifacts and surfaces the finalized model + robustness checks.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path('..').resolve()
OUTPUTS = ROOT / 'outputs'

final_models = pd.read_csv(OUTPUTS / 'step6_finalized_model_results.csv')
alternatives = pd.read_csv(OUTPUTS / 'step6_alternative_explanations.csv')
cutoff = pd.read_csv(OUTPUTS / 'step6_cutoff_sweep.csv')
metrics = json.loads((OUTPUTS / 'step6_key_metrics.json').read_text())

display(final_models)
display(alternatives)
display(cutoff)
metrics
