# %% [markdown]
# # STEP 4 Baseline Econometric Model
#
# This notebook mirrors the Step 4 scripted pipeline and is intended for quick interactive inspection of the model-ready panel and baseline estimates.
#
# Canonical reproducible run remains: `python scripts/run_step4_econometrics.py`.

# %%
import pandas as pd

panel = pd.read_csv('../outputs/step4_model_panel.csv')
twfe = pd.read_csv('../outputs/step4_twfe_models.csv')
event = pd.read_csv('../outputs/step4_event_study_issues_opened.csv')
panel.head(), twfe.head(), event.head()
